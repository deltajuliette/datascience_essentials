# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data
# ---
#
# We'll use [Yahoo! Finance](https://finance.yahoo.com/quote/AAPL) to get a few years worth of stock prices from Apple, Inc. (AAPL)

# %%
# Load data
df = pd.read_csv('../datasets/AAPL.csv')

print(df.shape)
df.head()
# Out:
# (504, 7)
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-08-08  206.050003  207.809998  204.520004  207.250000  201.371887
# 1  2018-08-09  209.529999  209.779999  207.199997  208.880005  202.955643
# 2  2018-08-10  207.360001  209.100006  206.669998  207.529999  202.351089
# 3  2018-08-13  209.309998  210.949997  207.699997  208.869995  203.657639
# 4  2018-08-14  210.160004  210.559998  208.259995  209.750000  204.515747
#
#      Volume
# 0  22525500
# 1  23492600
# 2  24611200
# 3  25890900
# 4  20748000

# %%
df.info()
# See Date column was previously read as a string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       504 non-null    datetime64[ns]
#  1   Open       504 non-null    float64
#  2   High       504 non-null    float64
#  3   Low        504 non-null    float64
#  4   Close      504 non-null    float64
#  5   Adj Close  504 non-null    float64
#  6   Volume     504 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 27.7 KB

# %%
# Change date column to be datetime dtype
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# ## Set the `Date` column to be the index
# ---
#
# We'll be exploring a few `pandas` methods related to time series data. In order for them to work we need to set the `Date` column to be the index.

# %%
df = df.set_index('Date')

print(df.shape)
df.head()
# Out:
# (504, 6)
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-08-08  206.050003  207.809998  204.520004  207.250000  201.371887
# 2018-08-09  209.529999  209.779999  207.199997  208.880005  202.955643
# 2018-08-10  207.360001  209.100006  206.669998  207.529999  202.351089
# 2018-08-13  209.309998  210.949997  207.699997  208.869995  203.657639
# 2018-08-14  210.160004  210.559998  208.259995  209.750000  204.515747
#
#               Volume
# Date
# 2018-08-08  22525500
# 2018-08-09  23492600
# 2018-08-10  24611200
# 2018-08-13  25890900
# 2018-08-14  20748000

# %%
df = df.sort_index()

print(df.shape)
df.head()
# Out:
# (504, 6)
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-08-08  206.050003  207.809998  204.520004  207.250000  201.371887
# 2018-08-09  209.529999  209.779999  207.199997  208.880005  202.955643
# 2018-08-10  207.360001  209.100006  206.669998  207.529999  202.351089
# 2018-08-13  209.309998  210.949997  207.699997  208.869995  203.657639
# 2018-08-14  210.160004  210.559998  208.259995  209.750000  204.515747
#
#               Volume
# Date
# 2018-08-08  22525500
# 2018-08-09  23492600
# 2018-08-10  24611200
# 2018-08-13  25890900
# 2018-08-14  20748000

# %% [markdown]
# ## Explore the data
# ---
#
# - `Close`: The price of AAPL when the stock market closes (at 4:30pm ET)
# - `Adj Close`: The closing price, when accounting for dividend payments, stock splits, etc.
# - `High`: The highest price of AAPL during that trading day
# - `Low`: The lowest price of AAPL during that trading day
# - `Open`: The price of AAPL when the stock market opens (at 9:30am ET)
# - `Volume`: How many shares of AAPL were traded that day

# %% [markdown]
# ## Filtering by dates
# ---
#
# Now that our `Date` column is the index, we can filter our data in unique ways. Try `df.loc['2018']` in the cell below:

# %%
df.loc['2018']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018

# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-08-12  207.646668  208.896668  206.130000  207.886668  202.226206
# 2018-08-19  210.776001  212.801999  209.784000  211.952002  206.662762
# 2018-08-26  216.050003  217.335999  214.538001  215.440002  210.063724
# 2018-09-02  221.213996  223.979999  220.612000  222.656000  217.099640
# 2018-09-09  226.370003  227.892498  223.435005  224.907501  219.294972
# ...                ...         ...         ...         ...         ...
# 2020-07-12  377.703998  381.017999  375.194000  378.920001  378.238037
# 2020-07-19  387.715997  392.807995  381.895996  386.488001  385.792407
# 2020-07-26  384.214001  388.617999  376.450000  382.471997  381.783643
# 2020-08-02  383.120001  389.918005  380.026001  388.442005  387.742895
# 2020-08-09  440.256000  448.726001  436.214001  442.944000  442.306787
#
#                 Volume
# Date
# 2018-08-12  23543100.0
# 2018-08-19  27874780.0
# 2018-08-26  22565040.0
# 2018-09-02  32538120.0
# 2018-09-09  33158225.0
# ...                ...
# 2020-07-12  28203600.0
# 2020-07-19  35930040.0
# 2020-07-26  33270440.0
# 2020-08-02  42381780.0
# 2020-08-09  50172840.0
#
# [105 rows x 6 columns]

# %% [markdown]
# ## Rolling
# ---
#
# With time series, we can "roll" statistics across time. For example, the rolling mean is the mean of a moving window across time periods. Pandas offers a variety of methods for creating rolling statistics, which we'll only scratch the surface of here.
#
# The syntax for these can be a little tricky at first. We'll be using a `rolling()` method with a statistical function chained to it.

# %%
# Create a 3 day moving average
# T-day Moving Averge: The value on any given day is the average of the past T-1 days and the day itself!
df.rolling(3).mean()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-08-08         NaN         NaN         NaN         NaN         NaN
# 2018-08-09         NaN         NaN         NaN         NaN         NaN
# 2018-08-10  207.646668  208.896668  206.130000  207.886668  202.226206
# 2018-08-13  208.733333  209.943334  207.189997  208.426666  202.988124
# 2018-08-14  208.943334  210.203334  207.543330  208.716665  203.508158
# ...                ...         ...         ...         ...         ...
# 2020-08-03  407.029999  419.133331  403.313334  415.183340  414.436106
# 2020-08-04  426.956665  438.456665  422.806661  433.150004  432.370432
# 2020-08-05  435.613332  443.760000  433.569997  438.220001  437.431305
# 2020-08-06  438.553335  447.460002  436.109995  444.839996  444.039388
# 2020-08-07  443.983337  451.306671  438.650004  446.769999  446.232554
#
#                   Volume
# Date
# 2018-08-08           NaN
# 2018-08-09           NaN
# 2018-08-10  2.354310e+07
# 2018-08-13  2.466490e+07
# 2018-08-14  2.375003e+07
# ...                  ...
# 2020-08-03  7.005150e+07
# 2020-08-04  7.129663e+07
# 2020-08-05  5.026790e+07
# 2020-08-06  4.145770e+07
# 2020-08-07  4.351950e+07
#
# [504 rows x 6 columns]

# %% [markdown]
# ## Challenge
# ---
#
# Plot a line chart with two lines:
# 1. The `Open` price
# 2. The 30 day rolling mean of the `Open` price

# %%
plt.figure(figsize=(12,8))
plt.plot(df['Open'])
plt.plot(df['Open'].rolling(30).mean());

# %% [markdown]
# ## `.diff()`
# ---
# The `.diff()` calculates the difference in a value between a value at time $T$ and that same value at $T-1$. For example, if I have a dataframe of stock prices:
#
# <table style="float: left;">
#   <thead>
#     <tr>
#       <th></th>
#       <th>Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1-1-2019</th>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1-2-2019</th>
#       <td>110</td>
#     </tr>
#   </tbody>
# </table>
#
# <div style="clear: both;"></div>
#
# When I call `.diff()`, I get the following:
# <table style="float: left;">
#   <thead>
#     <tr>
#       <th></th>
#       <th>Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1-1-2019</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1-2-2019</th>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# <div style="clear: both;"></div>
#
# It's helpful to find the change in price.

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-08-08  206.050003  207.809998  204.520004  207.250000  201.371887
# 2018-08-09  209.529999  209.779999  207.199997  208.880005  202.955643
# 2018-08-10  207.360001  209.100006  206.669998  207.529999  202.351089
# 2018-08-13  209.309998  210.949997  207.699997  208.869995  203.657639
# 2018-08-14  210.160004  210.559998  208.259995  209.750000  204.515747
#
#               Volume
# Date
# 2018-08-08  22525500
# 2018-08-09  23492600
# 2018-08-10  24611200
# 2018-08-13  25890900
# 2018-08-14  20748000

# %%
df.diff()
# Out:
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 2018-08-08        NaN        NaN        NaN        NaN        NaN         NaN
# 2018-08-09   3.479996   1.970001   2.679993   1.630005   1.583756    967100.0
# 2018-08-10  -2.169998  -0.679993  -0.529999  -1.350006  -0.604554   1118600.0
# 2018-08-13   1.949997   1.849991   1.029999   1.339996   1.306550   1279700.0
# 2018-08-14   0.850006  -0.389999   0.559998   0.880005   0.858108  -5142900.0
# ...               ...        ...        ...        ...        ...         ...
# 2020-08-03  21.259979  20.889984  28.270019  10.709991  10.690735 -16546400.0
# 2020-08-04   3.730011  -3.389984   1.979981   2.910004   2.904755 -33769900.0
# 2020-08-05   0.980011  -1.589997   2.040008   1.589996   1.587128 -12769900.0
# 2020-08-06   4.109985  16.079987   3.600006  15.359985  15.332367  20109200.0
# 2020-08-07  11.200012  -2.949982   1.980011 -11.159973 -10.339997  -1153900.0
#
# [504 rows x 6 columns]

# %% [markdown]
# ## `.pct_change()`
# ---
#
# `.pct_change()` works similar to `.diff()`, except we're calculating the difference as a change in percentage: $X_{t}/X_{t-1} - 1$
#
# So if I have my table of stock prices:
#
# <table style="float: left;">
#   <thead>
#     <tr>
#       <th></th>
#       <th>Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1-1-2019</th>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1-2-2019</th>
#       <td>110</td>
#     </tr>
#   </tbody>
# </table>
#
# <div style="clear: both;"></div>
#
# The `.pct_change()` will look like this:
#
# <table style="float: left;">
#   <thead>
#     <tr>
#       <th></th>
#       <th>Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1-1-2019</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1-2-2019</th>
#       <td>.1</td>
#     </tr>
#   </tbody>
# </table>
#
# <div style="clear: both;"></div>
#
#
# We'd interpret 1-2-2019 as a 10% increase (110/100 - 1 = .10) in price from the day before. Again, the first row is a `NaN` since there is no prior row to calcuate the percent change from.

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-08-08  206.050003  207.809998  204.520004  207.250000  201.371887
# 2018-08-09  209.529999  209.779999  207.199997  208.880005  202.955643
# 2018-08-10  207.360001  209.100006  206.669998  207.529999  202.351089
# 2018-08-13  209.309998  210.949997  207.699997  208.869995  203.657639
# 2018-08-14  210.160004  210.559998  208.259995  209.750000  204.515747
#
#               Volume
# Date
# 2018-08-08  22525500
# 2018-08-09  23492600
# 2018-08-10  24611200
# 2018-08-13  25890900
# 2018-08-14  20748000

# %%
df.pct_change()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2018-08-08       NaN       NaN       NaN       NaN        NaN       NaN
# 2018-08-09  0.016889  0.009480  0.013104  0.007865   0.007865  0.042934
# 2018-08-10 -0.010357 -0.003241 -0.002558 -0.006463  -0.002979  0.047615
# 2018-08-13  0.009404  0.008847  0.004984  0.006457   0.006457  0.051997
# 2018-08-14  0.004061 -0.001849  0.002696  0.004213   0.004213 -0.198637
# ...              ...       ...       ...       ...        ...       ...
# 2020-08-03  0.051660  0.049077  0.070097  0.025198   0.025198 -0.176808
# 2020-08-04  0.008618 -0.007591  0.004588  0.006678   0.006678 -0.438355
# 2020-08-05  0.002245 -0.003588  0.004705  0.003625   0.003625 -0.295136
# 2020-08-06  0.009394  0.036415  0.008265  0.034889   0.034889  0.659361
# 2020-08-07  0.025361 -0.006446  0.004508 -0.024495  -0.022736 -0.022801
#
# [504 rows x 6 columns]

# %% [markdown]
# ## Challenge
# ---
#
# Create three **separate** plots:
# 1. One for the `Close` price
# 2. One for the `Close` price, using `.diff()`
# 3. One for the `Close` price as a percent change.
#
# What happens to your overall data when you diff?

# %%
fig, axes = plt.subplots(nrows=3, figsize=(15,12))
axes[0].plot(df['Close'])
axes[1].plot(df['Close'].diff())
axes[2].plot(df['Close'].pct_change());

# %% [markdown]
# [Why would we difference?](https://otexts.com/fpp2/stationarity.html) Well, there is one assumption that is **required** for nearly every time series model: **stationarity**.
# - If our time series is stationary, then we do not need to difference
# - If our time series is not stationary, then we difference either once (`df.diff()`) or twice (`df.diff().diff()`).
# - So instead of trying to model and forecast on the original time series data, we build models on this differenced data. In other words, we try to predict how much higher or lower tomorrow will be intead of trying to predict the exact value of tomorrow's price.
#
# ## What is stationarity?
# ---
#
# Informally, stationarity means that there **aren't systematic changes in our time series over time**.
# - Our mean stays the same. (There is no trend.)
# - The autocorrelation between $Y_t$ and $Y_{t-k}$ depends only on the size of our lag $k$. (There is no seasonality.)
# - A [white noise process](https://stats.stackexchange.com/questions/7070/what-is-a-white-noise-process) is a common example of a stationary time series.
#
# The problem is, many time series **aren't** stationary.
# - The amount that stock prices vary on a day-to-day basis aren't going to be the same.
# - Crop prices may increase or decrease over time; assuming a constant mean here doesn't make sense.
# - Thus `diff()` is one way we can convert a non-stationary series to stationary

# %% [markdown]
# ## Shifting
# ---
#
# `df.shift()` is used to bring values from previous dates forward in time.

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-08-08  209.529999  209.779999  207.199997  208.880005  202.955643
# 2018-08-09  207.360001  209.100006  206.669998  207.529999  202.351089
# 2018-08-10  209.309998  210.949997  207.699997  208.869995  203.657639
# 2018-08-13  210.160004  210.559998  208.259995  209.750000  204.515747
# 2018-08-14  209.220001  210.740005  208.330002  210.240005  204.993484
# ...                ...         ...         ...         ...         ...
# 2020-08-03  436.529999  443.160004  433.549988  438.660004  437.870514
# 2020-08-04  437.510010  441.570007  435.589996  440.250000  439.457642
# 2020-08-05  441.619995  457.649994  439.190002  455.609985  454.790009
# 2020-08-06  452.820007  454.700012  441.170013  444.450012  444.450012
# 2020-08-07         NaN         NaN         NaN         NaN         NaN
#
#                 Volume
# Date
# 2018-08-08  23492600.0
# 2018-08-09  24611200.0
# 2018-08-10  25890900.0
# 2018-08-13  20748000.0
# 2018-08-14  28807600.0
# ...                ...
# 2020-08-03  43267900.0
# 2020-08-04  30498000.0
# 2020-08-05  50607200.0
# 2020-08-06  49453300.0
# 2020-08-07         NaN
#
# [504 rows x 6 columns]

# %% [markdown]
# ## Creating a simple dataset
# ---
#
# - Let's create a simple dataset that tries to predict today's `Close` price using yesterday's `Close` price with today's `Open` price.
# - If today's close price is higher than yesterday's close then we want to predict 1. Else 0. So its a simple binary classification task
#
# **NOTE:** Remember we want stationarity!

# %%
# Convert Open and Close prices to Pct changes to make them stationary
today = df[['Open', 'Close']].pct_change()
today.head()
# Out:
#                 Open     Close
# Date
# 2018-08-08       NaN       NaN
# 2018-08-09  0.016889  0.007865
# 2018-08-10 -0.010357 -0.006463
# 2018-08-13  0.009404  0.006457
# 2018-08-14  0.004061  0.004213

# %%
# Move yesterday's close price to today
yesterday = today[['Close']].shift()
yesterday.columns=['Yesterday Close']
yesterday.head()
# Out:
#             Yesterday Close
# Date
# 2018-08-08              NaN
# 2018-08-09              NaN
# 2018-08-10         0.007865
# 2018-08-13        -0.006463
# 2018-08-14         0.006457

# %%
# Join them both and drop na
today = today.join(yesterday).dropna()
today.head()
# Out:
#                 Open     Close  Yesterday Close
# Date
# 2018-08-10 -0.010357 -0.006463         0.007865
# 2018-08-13  0.009404  0.006457        -0.006463
# 2018-08-14  0.004061  0.004213         0.006457
# 2018-08-15 -0.004473  0.002336         0.004213
# 2018-08-16  0.012093  0.014650         0.002336

# %%
# Convert Today Close to Binary value
today['Close'] = (today['Close'] >=0).astype(int)
today.head()
# Out:
#                 Open  Close  Yesterday Close
# Date
# 2018-08-10 -0.010357      0         0.007865
# 2018-08-13  0.009404      1        -0.006463
# 2018-08-14  0.004061      1         0.006457
# 2018-08-15 -0.004473      1         0.004213
# 2018-08-16  0.012093      1         0.002336

# %%
# Reorder columns so that response (today's close) is the last column
today = today[['Open', 'Yesterday Close', 'Close']]
today.head()
# Out:
#                 Open  Yesterday Close  Close
# Date
# 2018-08-10 -0.010357         0.007865      0
# 2018-08-13  0.009404        -0.006463      1
# 2018-08-14  0.004061         0.006457      1
# 2018-08-15 -0.004473         0.004213      1
# 2018-08-16  0.012093         0.002336      1
